# %%
dataset_base = "/kaggle/input"
print("Available datasets: ", os.listdir(dataset_base))
print("Contents of 'dataset': ", os.listdir(os.path.join(dataset_base, 'dataset')))
print("Contents of 'biggan': ", os.listdir(os.path.join(dataset_base, 'biggan')))
print("Contents of 'cyclegan-dataset': ", os.listdir(os.path.join(dataset_base, 'cyclegan-dataset')))
print("Contents of 'stylegan-dataset': ", os.listdir(os.path.join(dataset_base, 'stylegan-dataset')))
# Out:
# Available datasets:  ['stylegan-dataset', 'biggan', 'cyclegan-dataset', 'dataset']
# Contents of 'dataset':  ['Celeb-DF', 'Celeb-DF-v2']
# Contents of 'biggan':  ['variables', 'saved_model.pb', 'tfhub_module.pb']
# Contents of 'cyclegan-dataset':  ['testB', 'testA', 'trainB', 'trainA', 'metadata.csv']
# Contents of 'stylegan-dataset':  ['Final Dataset']

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU detected")
# Out:
# CUDA available: False
# GPU device name: No GPU detected
